# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import torch.utils.data as data_utils
import time

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
data_transforms = transforms.Compose([     
                        transforms.Resize(256),
                        transforms.CenterCrop(224),
                        transforms.ToTensor(),
                        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                             std=[0.229, 0.224, 0.225] )
    ])

# %%
batch_size = 10

#ТРЕЙНИНГ
train_dataset = torchvision.datasets.ImageFolder(root='./animals/train', 
                                                 transform=data_transforms)
#СЛАЙСИНГ (через random_split)
len_sliced = 2000
tr_sliced = torch.utils.data.random_split(train_dataset, [len_sliced, len(train_dataset)-len_sliced])[0]

train_loader = torch.utils.data.DataLoader(tr_sliced, batch_size=batch_size, 
                                    shuffle=True,  num_workers=2)


#ТЕСТ
test_dataset = torchvision.datasets.ImageFolder(root='./animals/val',
                                             transform=data_transforms)
len_sliced = 1000
test_sliced = torch.utils.data.random_split(test_dataset, [len_sliced, len(test_dataset)-len_sliced])[0]

test_loader  = torch.utils.data.DataLoader(test_sliced, batch_size=batch_size, 
                                    shuffle=True, num_workers=2)

# %%
print(train_dataset.classes)
print(test_dataset.classes)
# Out:
# ['cat', 'dog', 'wild']
# ['cat', 'dog', 'wild']

# %%
# Сохранение названия классов
class_names = train_dataset.classes

# %%
inputs, classes = next(iter(train_loader))

img = torchvision.utils.make_grid(inputs, nrow = 3)
img = img.numpy().transpose((1, 2, 0)) 
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class CNN(torch.nn.Module): 
    def __init__(self, num_classes=3): 
        super().__init__() 
        self.model = torch.nn.Sequential( 
            #слой сверстки
            torch.nn.Conv2d(in_channels = 3, out_channels = 6, kernel_size = 3, padding = 1),  
            torch.nn.ReLU(), 
            torch.nn.MaxPool2d(kernel_size=2), #сожмет изображение и подчеркнет признаки
  
            torch.nn.Conv2d(in_channels = 6, out_channels = 6, kernel_size = 3, padding = 1), 
            torch.nn.ReLU(), 
            torch.nn.MaxPool2d(kernel_size=2), 
              
            torch.nn.Conv2d(in_channels = 6, out_channels = 6, kernel_size = 3, padding = 1), 
            torch.nn.ReLU(), 
            torch.nn.MaxPool2d(kernel_size=2), 
  
            # слой сглаживания
            torch.nn.Flatten(), 
            torch.nn.Linear(4704, 512), 
            torch.nn.ReLU(), 
            torch.nn.Linear(512, num_classes) 
        ) 
  
    def forward(self, x): 
        return self.model(x)

# %%
#гиперпараметры
num_epochs = 4
learning_rate = 0.001
weight_decay = 0.01

net = CNN().to(device)

lossFn = nn.CrossEntropyLoss()
criterion = torch.nn.CrossEntropyLoss() 
optimizer = torch.optim.SGD(net.parameters(), lr=0.01)
  

train_loss_list = [] 
t = time.time()
for epoch in range(num_epochs): 
    print(f'Epoch {epoch+1}/{num_epochs}:', end = ' ') 
    train_loss = 0
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        
        outputs = net(images)
        
        loss = lossFn(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()
        
        if i%10==0:
            print('Эпоха ' + str(epoch) + ' из ' + str(num_epochs) + ' Шаг ' +
                  str(i) + ' Ошибка: ', loss.item())
        
print('Time:',time.time() - t)
# Out:
# Epoch 1/20: Эпоха 0 из 20 Шаг 0 Ошибка:  1.104314923286438
# Эпоха 0 из 20 Шаг 10 Ошибка:  1.1158193349838257
# Эпоха 0 из 20 Шаг 20 Ошибка:  1.1013481616973877
# Эпоха 0 из 20 Шаг 30 Ошибка:  1.1081172227859497
# Эпоха 0 из 20 Шаг 40 Ошибка:  1.095729112625122
# Эпоха 0 из 20 Шаг 50 Ошибка:  1.0971708297729492
# Эпоха 0 из 20 Шаг 60 Ошибка:  1.0853655338287354
# Эпоха 0 из 20 Шаг 70 Ошибка:  1.0870352983474731
# Эпоха 0 из 20 Шаг 80 Ошибка:  1.092797875404358
# Эпоха 0 из 20 Шаг 90 Ошибка:  1.0976731777191162
# Эпоха 0 из 20 Шаг 100 Ошибка:  1.084835410118103
# Эпоха 0 из 20 Шаг 110 Ошибка:  1.0767961740493774
# Эпоха 0 из 20 Шаг 120 Ошибка:  1.0823838710784912
# Эпоха 0 из 20 Шаг 130 Ошибка:  1.0815494060516357
# Эпоха 0 из 20 Шаг 140 Ошибка:  1.0802502632141113
# Эпоха 0 из 20 Шаг 150 Ошибка:  1.1325863599777222
# Эпоха 0 из 20 Шаг 160 Ошибка:  1.061161756515503
# Эпоха 0 из 20 Шаг 170 Ошибка:  1.1128498315811157
# Эпоха 0 из 20 Шаг 180 Ошибка:  1.0708814859390259
# Эпоха 0 из 20 Шаг 190 Ошибка:  1.1012500524520874
# Epoch 2/20: Эпоха 1 из 20 Шаг 0 Ошибка:  1.0886285305023193
# Эпоха 1 из 20 Шаг 10 Ошибка:  1.0976176261901855
# Эпоха 1 из 20 Шаг 20 Ошибка:  1.093008041381836
# Эпоха 1 из 20 Шаг 30 Ошибка:  1.0736926794052124
# Эпоха 1 из 20 Шаг 40 Ошибка:  1.072048544883728
# Эпоха 1 из 20 Шаг 50 Ошибка:  1.020550012588501
# Эпоха 1 из 20 Шаг 60 Ошибка:  1.0833244323730469
# Эпоха 1 из 20 Шаг 70 Ошибка:  1.087591528892517
# Эпоха 1 из 20 Шаг 80 Ошибка:  1.0731453895568848
# Эпоха 1 из 20 Шаг 90 Ошибка:  1.0550298690795898
# Эпоха 1 из 20 Шаг 100 Ошибка:  1.080109715461731
# Эпоха 1 из 20 Шаг 110 Ошибка:  1.088561773300171
# Эпоха 1 из 20 Шаг 120 Ошибка:  1.054361343383789
# Эпоха 1 из 20 Шаг 130 Ошибка:  1.105403184890747
# Эпоха 1 из 20 Шаг 140 Ошибка:  1.1138108968734741
# Эпоха 1 из 20 Шаг 150 Ошибка:  1.1178911924362183
# Эпоха 1 из 20 Шаг 160 Ошибка:  1.02670156955719
# Эпоха 1 из 20 Шаг 170 Ошибка:  1.0752543210983276
# Эпоха 1 из 20 Шаг 180 Ошибка:  1.0087559223175049
# Эпоха 1 из 20 Шаг 190 Ошибка:  1.0159475803375244
# Epoch 3/20: Эпоха 2 из 20 Шаг 0 Ошибка:  1.049245834350586
# Эпоха 2 из 20 Шаг 10 Ошибка:  0.9905899167060852
# Эпоха 2 из 20 Шаг 20 Ошибка:  0.9062134623527527
# Эпоха 2 из 20 Шаг 30 Ошибка:  0.8951460719108582
# Эпоха 2 из 20 Шаг 40 Ошибка:  1.021496295928955
# Эпоха 2 из 20 Шаг 50 Ошибка:  0.9430238008499146
# Эпоха 2 из 20 Шаг 60 Ошибка:  0.8010154962539673
# Эпоха 2 из 20 Шаг 70 Ошибка:  0.8720657229423523
# Эпоха 2 из 20 Шаг 80 Ошибка:  0.862563967704773
# Эпоха 2 из 20 Шаг 90 Ошибка:  0.8377549052238464
# Эпоха 2 из 20 Шаг 100 Ошибка:  0.8581711649894714
# Эпоха 2 из 20 Шаг 110 Ошибка:  0.6007416844367981
# Эпоха 2 из 20 Шаг 120 Ошибка:  0.7598594427108765
# Эпоха 2 из 20 Шаг 130 Ошибка:  0.7612020373344421
# Эпоха 2 из 20 Шаг 140 Ошибка:  1.0178676843643188
# Эпоха 2 из 20 Шаг 150 Ошибка:  0.6143043041229248
# Эпоха 2 из 20 Шаг 160 Ошибка:  1.2223179340362549
# Эпоха 2 из 20 Шаг 170 Ошибка:  0.814461886882782
# Эпоха 2 из 20 Шаг 180 Ошибка:  0.8100098371505737
# Эпоха 2 из 20 Шаг 190 Ошибка:  0.7350486516952515
# Epoch 4/20: Эпоха 3 из 20 Шаг 0 Ошибка:  0.6696686744689941
# Эпоха 3 из 20 Шаг 10 Ошибка:  1.2689437866210938
# Эпоха 3 из 20 Шаг 20 Ошибка:  0.8123008608818054
# Эпоха 3 из 20 Шаг 30 Ошибка:  0.6634901762008667
# Эпоха 3 из 20 Шаг 40 Ошибка:  0.7404516339302063
# Эпоха 3 из 20 Шаг 50 Ошибка:  0.547488808631897
# Эпоха 3 из 20 Шаг 60 Ошибка:  0.8677452206611633
# Эпоха 3 из 20 Шаг 70 Ошибка:  0.664512038230896
# Эпоха 3 из 20 Шаг 80 Ошибка:  1.6163307428359985
# Эпоха 3 из 20 Шаг 90 Ошибка:  0.8137423396110535
# Эпоха 3 из 20 Шаг 100 Ошибка:  0.8017508387565613
# Эпоха 3 из 20 Шаг 110 Ошибка:  0.8949452638626099
# Эпоха 3 из 20 Шаг 120 Ошибка:  0.6748509407043457
# Эпоха 3 из 20 Шаг 130 Ошибка:  0.8026069402694702
# Эпоха 3 из 20 Шаг 140 Ошибка:  1.0176821947097778
# Эпоха 3 из 20 Шаг 150 Ошибка:  0.7619767785072327
# Эпоха 3 из 20 Шаг 160 Ошибка:  0.557808518409729
# Эпоха 3 из 20 Шаг 170 Ошибка:  0.8661225438117981
# Эпоха 3 из 20 Шаг 180 Ошибка:  0.5522667765617371
# Эпоха 3 из 20 Шаг 190 Ошибка:  0.7142215967178345
# Epoch 5/20: Эпоха 4 из 20 Шаг 0 Ошибка:  0.8150848150253296
# Эпоха 4 из 20 Шаг 10 Ошибка:  0.8090866208076477
# Эпоха 4 из 20 Шаг 20 Ошибка:  0.5137461423873901
# Эпоха 4 из 20 Шаг 30 Ошибка:  0.8163427114486694
# Эпоха 4 из 20 Шаг 40 Ошибка:  0.5625488758087158
# Эпоха 4 из 20 Шаг 50 Ошибка:  0.6803185939788818
# Эпоха 4 из 20 Шаг 60 Ошибка:  0.9146386981010437
# Эпоха 4 из 20 Шаг 70 Ошибка:  0.6222248673439026
# Эпоха 4 из 20 Шаг 80 Ошибка:  0.4282057285308838
# Эпоха 4 из 20 Шаг 90 Ошибка:  0.27781379222869873
# Эпоха 4 из 20 Шаг 100 Ошибка:  0.4783419072628021
# Эпоха 4 из 20 Шаг 110 Ошибка:  0.4997328221797943
# Эпоха 4 из 20 Шаг 120 Ошибка:  0.6646791696548462
# Эпоха 4 из 20 Шаг 130 Ошибка:  0.2540529668331146
# Эпоха 4 из 20 Шаг 140 Ошибка:  0.3542153835296631
# Эпоха 4 из 20 Шаг 150 Ошибка:  0.6387192010879517
# Эпоха 4 из 20 Шаг 160 Ошибка:  0.7983584403991699
# Эпоха 4 из 20 Шаг 170 Ошибка:  0.15852388739585876
# Эпоха 4 из 20 Шаг 180 Ошибка:  0.5903424024581909
# Эпоха 4 из 20 Шаг 190 Ошибка:  0.49075478315353394
# Epoch 6/20: Эпоха 5 из 20 Шаг 0 Ошибка:  0.21833772957324982
# Эпоха 5 из 20 Шаг 10 Ошибка:  0.6469534039497375
# Эпоха 5 из 20 Шаг 20 Ошибка:  0.30555492639541626
# Эпоха 5 из 20 Шаг 30 Ошибка:  0.7256426811218262
# Эпоха 5 из 20 Шаг 40 Ошибка:  0.567245602607727
# Эпоха 5 из 20 Шаг 50 Ошибка:  0.3679949641227722
# Эпоха 5 из 20 Шаг 60 Ошибка:  0.5032405853271484
# Эпоха 5 из 20 Шаг 70 Ошибка:  0.3383854329586029
# Эпоха 5 из 20 Шаг 80 Ошибка:  0.30714812874794006
# Эпоха 5 из 20 Шаг 90 Ошибка:  1.167681336402893
# Эпоха 5 из 20 Шаг 100 Ошибка:  0.7280399799346924
# Эпоха 5 из 20 Шаг 110 Ошибка:  0.24723610281944275
# Эпоха 5 из 20 Шаг 120 Ошибка:  0.3961591124534607
# Эпоха 5 из 20 Шаг 130 Ошибка:  0.2742043137550354
# Эпоха 5 из 20 Шаг 140 Ошибка:  0.24503150582313538
# Эпоха 5 из 20 Шаг 150 Ошибка:  0.4108343720436096
# Эпоха 5 из 20 Шаг 160 Ошибка:  0.23483076691627502
# Эпоха 5 из 20 Шаг 170 Ошибка:  0.19409136474132538
# Эпоха 5 из 20 Шаг 180 Ошибка:  0.12834273278713226
# Эпоха 5 из 20 Шаг 190 Ошибка:  0.11803688853979111
# Epoch 7/20: Эпоха 6 из 20 Шаг 0 Ошибка:  0.17184089124202728
# Эпоха 6 из 20 Шаг 10 Ошибка:  0.039546363055706024
# Эпоха 6 из 20 Шаг 20 Ошибка:  0.6898007392883301
# Эпоха 6 из 20 Шаг 30 Ошибка:  0.3980955183506012
# Эпоха 6 из 20 Шаг 40 Ошибка:  0.2714894115924835
# Эпоха 6 из 20 Шаг 50 Ошибка:  0.42059049010276794
# Эпоха 6 из 20 Шаг 60 Ошибка:  0.41064101457595825
# Эпоха 6 из 20 Шаг 70 Ошибка:  0.12721920013427734
# Эпоха 6 из 20 Шаг 80 Ошибка:  0.28237777948379517
# Эпоха 6 из 20 Шаг 90 Ошибка:  0.09877211600542068
# Эпоха 6 из 20 Шаг 100 Ошибка:  0.07675249874591827
# Эпоха 6 из 20 Шаг 110 Ошибка:  0.9121254086494446
# Эпоха 6 из 20 Шаг 120 Ошибка:  0.10563862323760986
# Эпоха 6 из 20 Шаг 130 Ошибка:  0.2999565005302429
# Эпоха 6 из 20 Шаг 140 Ошибка:  1.6563316583633423
# Эпоха 6 из 20 Шаг 150 Ошибка:  0.1415504664182663
# Эпоха 6 из 20 Шаг 160 Ошибка:  0.2391718626022339
# Эпоха 6 из 20 Шаг 170 Ошибка:  0.33851513266563416
# Эпоха 6 из 20 Шаг 180 Ошибка:  0.49546951055526733
# Эпоха 6 из 20 Шаг 190 Ошибка:  0.08871199190616608
# Epoch 8/20: Эпоха 7 из 20 Шаг 0 Ошибка:  0.11195434629917145
# Эпоха 7 из 20 Шаг 10 Ошибка:  0.1999814659357071
# Эпоха 7 из 20 Шаг 20 Ошибка:  0.26285234093666077
# Эпоха 7 из 20 Шаг 30 Ошибка:  0.09706385433673859
# Эпоха 7 из 20 Шаг 40 Ошибка:  0.22017478942871094
# Эпоха 7 из 20 Шаг 50 Ошибка:  0.5340911149978638
# Эпоха 7 из 20 Шаг 60 Ошибка:  0.23929044604301453
# Эпоха 7 из 20 Шаг 70 Ошибка:  0.15239141881465912
# Эпоха 7 из 20 Шаг 80 Ошибка:  0.14976929128170013
# Эпоха 7 из 20 Шаг 90 Ошибка:  0.11989261955022812
# Эпоха 7 из 20 Шаг 100 Ошибка:  0.1634378731250763
# Эпоха 7 из 20 Шаг 110 Ошибка:  0.07755143940448761
# Эпоха 7 из 20 Шаг 120 Ошибка:  0.48631033301353455
# Эпоха 7 из 20 Шаг 130 Ошибка:  0.38450926542282104
# Эпоха 7 из 20 Шаг 140 Ошибка:  0.24258413910865784
# Эпоха 7 из 20 Шаг 150 Ошибка:  0.2821512818336487
# Эпоха 7 из 20 Шаг 160 Ошибка:  0.05206689238548279
# Эпоха 7 из 20 Шаг 170 Ошибка:  0.033847760409116745
# Эпоха 7 из 20 Шаг 180 Ошибка:  0.07980983704328537
# Эпоха 7 из 20 Шаг 190 Ошибка:  0.23516961932182312
# Epoch 9/20: Эпоха 8 из 20 Шаг 0 Ошибка:  0.056041914969682693
# Эпоха 8 из 20 Шаг 10 Ошибка:  0.08989299088716507
# Эпоха 8 из 20 Шаг 20 Ошибка:  0.014727788977324963
# Эпоха 8 из 20 Шаг 30 Ошибка:  0.09314614534378052
# Эпоха 8 из 20 Шаг 40 Ошибка:  0.014689505100250244
# Эпоха 8 из 20 Шаг 50 Ошибка:  0.20351019501686096
# Эпоха 8 из 20 Шаг 60 Ошибка:  0.5521525144577026
# Эпоха 8 из 20 Шаг 70 Ошибка:  0.13378044962882996
# Эпоха 8 из 20 Шаг 80 Ошибка:  0.0302983820438385
# Эпоха 8 из 20 Шаг 90 Ошибка:  0.10145629942417145
# Эпоха 8 из 20 Шаг 100 Ошибка:  0.057998090982437134
# Эпоха 8 из 20 Шаг 110 Ошибка:  0.04258740693330765
# Эпоха 8 из 20 Шаг 120 Ошибка:  0.0777820572257042
# Эпоха 8 из 20 Шаг 130 Ошибка:  0.1741880625486374
# Эпоха 8 из 20 Шаг 140 Ошибка:  0.564623236656189
# Эпоха 8 из 20 Шаг 150 Ошибка:  0.1832292079925537
# Эпоха 8 из 20 Шаг 160 Ошибка:  0.01536525972187519
# Эпоха 8 из 20 Шаг 170 Ошибка:  0.175632506608963
# Эпоха 8 из 20 Шаг 180 Ошибка:  0.03373425826430321
# Эпоха 8 из 20 Шаг 190 Ошибка:  0.3293724060058594
# Epoch 10/20: Эпоха 9 из 20 Шаг 0 Ошибка:  0.014797871001064777
# Эпоха 9 из 20 Шаг 10 Ошибка:  0.03518715128302574
# Эпоха 9 из 20 Шаг 20 Ошибка:  0.04058345407247543
# Эпоха 9 из 20 Шаг 30 Ошибка:  0.041379429399967194
# Эпоха 9 из 20 Шаг 40 Ошибка:  0.008061197586357594
# Эпоха 9 из 20 Шаг 50 Ошибка:  0.078462615609169
# Эпоха 9 из 20 Шаг 60 Ошибка:  0.043521035462617874
# Эпоха 9 из 20 Шаг 70 Ошибка:  0.005685704294592142
# Эпоха 9 из 20 Шаг 80 Ошибка:  0.04970454424619675
# Эпоха 9 из 20 Шаг 90 Ошибка:  0.058252859860658646
# Эпоха 9 из 20 Шаг 100 Ошибка:  0.029893353581428528
# Эпоха 9 из 20 Шаг 110 Ошибка:  0.06639102101325989
# Эпоха 9 из 20 Шаг 120 Ошибка:  0.005866963881999254
# Эпоха 9 из 20 Шаг 130 Ошибка:  0.005989018827676773
# Эпоха 9 из 20 Шаг 140 Ошибка:  0.01291858684271574
# Эпоха 9 из 20 Шаг 150 Ошибка:  0.021164964884519577
# Эпоха 9 из 20 Шаг 160 Ошибка:  0.05215203016996384
# Эпоха 9 из 20 Шаг 170 Ошибка:  0.0058976830914616585
# Эпоха 9 из 20 Шаг 180 Ошибка:  0.021016789600253105
# Эпоха 9 из 20 Шаг 190 Ошибка:  0.14792075753211975
# Epoch 11/20: Эпоха 10 из 20 Шаг 0 Ошибка:  0.08937834203243256
# Эпоха 10 из 20 Шаг 10 Ошибка:  0.16482298076152802
# Эпоха 10 из 20 Шаг 20 Ошибка:  0.0645633116364479
# Эпоха 10 из 20 Шаг 30 Ошибка:  0.053116053342819214
# Эпоха 10 из 20 Шаг 40 Ошибка:  0.022987233474850655
# Эпоха 10 из 20 Шаг 50 Ошибка:  0.01808292791247368
# Эпоха 10 из 20 Шаг 60 Ошибка:  0.18614548444747925
# Эпоха 10 из 20 Шаг 70 Ошибка:  0.03769618272781372
# Эпоха 10 из 20 Шаг 80 Ошибка:  0.07455714792013168
# Эпоха 10 из 20 Шаг 90 Ошибка:  0.010666037909686565
# Эпоха 10 из 20 Шаг 100 Ошибка:  0.0660422220826149
# Эпоха 10 из 20 Шаг 110 Ошибка:  0.09460897743701935
# Эпоха 10 из 20 Шаг 120 Ошибка:  0.036944933235645294
# Эпоха 10 из 20 Шаг 130 Ошибка:  0.029373478144407272
# Эпоха 10 из 20 Шаг 140 Ошибка:  0.005378059111535549
# Эпоха 10 из 20 Шаг 150 Ошибка:  0.008607704192399979
# Эпоха 10 из 20 Шаг 160 Ошибка:  0.0012986265355721116
# Эпоха 10 из 20 Шаг 170 Ошибка:  0.001483387197367847
# Эпоха 10 из 20 Шаг 180 Ошибка:  0.030679520219564438
# Эпоха 10 из 20 Шаг 190 Ошибка:  0.016983946785330772
# Epoch 12/20: Эпоха 11 из 20 Шаг 0 Ошибка:  0.0002754387096501887
# Эпоха 11 из 20 Шаг 10 Ошибка:  0.025434115901589394
# Эпоха 11 из 20 Шаг 20 Ошибка:  0.025331277400255203
# Эпоха 11 из 20 Шаг 30 Ошибка:  0.01498931460082531
# Эпоха 11 из 20 Шаг 40 Ошибка:  0.20246410369873047
# Эпоха 11 из 20 Шаг 50 Ошибка:  0.004485458135604858
# Эпоха 11 из 20 Шаг 60 Ошибка:  0.005282214842736721
# Эпоха 11 из 20 Шаг 70 Ошибка:  0.007303272839635611
# Эпоха 11 из 20 Шаг 80 Ошибка:  0.03328711539506912
# Эпоха 11 из 20 Шаг 90 Ошибка:  0.02978699840605259
# Эпоха 11 из 20 Шаг 100 Ошибка:  3.838127668132074e-05
# Эпоха 11 из 20 Шаг 110 Ошибка:  0.0018814277136698365
# Эпоха 11 из 20 Шаг 120 Ошибка:  0.0058495234698057175
# Эпоха 11 из 20 Шаг 130 Ошибка:  0.00204826588742435
# Эпоха 11 из 20 Шаг 140 Ошибка:  0.009468164294958115
# Эпоха 11 из 20 Шаг 150 Ошибка:  0.008567415177822113
# Эпоха 11 из 20 Шаг 160 Ошибка:  0.0019410731038078666
# Эпоха 11 из 20 Шаг 170 Ошибка:  0.0003702292451635003
# Эпоха 11 из 20 Шаг 180 Ошибка:  0.002611073898151517
# Эпоха 11 из 20 Шаг 190 Ошибка:  0.06825220584869385
# Epoch 13/20: Эпоха 12 из 20 Шаг 0 Ошибка:  0.0006920445594005287
# Эпоха 12 из 20 Шаг 10 Ошибка:  0.0014249461237341166
# Эпоха 12 из 20 Шаг 20 Ошибка:  0.009847409091889858
# Эпоха 12 из 20 Шаг 30 Ошибка:  0.0019843815825879574
# Эпоха 12 из 20 Шаг 40 Ошибка:  0.0002576512051746249
# Эпоха 12 из 20 Шаг 50 Ошибка:  0.015702243894338608
# Эпоха 12 из 20 Шаг 60 Ошибка:  0.0029826939571648836
# Эпоха 12 из 20 Шаг 70 Ошибка:  0.0013281566789373755
# Эпоха 12 из 20 Шаг 80 Ошибка:  0.0051445188000798225
# Эпоха 12 из 20 Шаг 90 Ошибка:  0.004192465916275978
# Эпоха 12 из 20 Шаг 100 Ошибка:  0.0029138256795704365
# Эпоха 12 из 20 Шаг 110 Ошибка:  0.0013151733437553048
# Эпоха 12 из 20 Шаг 120 Ошибка:  0.000438191054854542
# Эпоха 12 из 20 Шаг 130 Ошибка:  0.001622670330107212
# Эпоха 12 из 20 Шаг 140 Ошибка:  0.00020066264551132917
# Эпоха 12 из 20 Шаг 150 Ошибка:  0.0014338096370920539
# Эпоха 12 из 20 Шаг 160 Ошибка:  0.0010308658238500357
# Эпоха 12 из 20 Шаг 170 Ошибка:  0.0018880169373005629
# Эпоха 12 из 20 Шаг 180 Ошибка:  0.0012051460798829794
# Эпоха 12 из 20 Шаг 190 Ошибка:  0.001053531770594418
# Epoch 14/20: Эпоха 13 из 20 Шаг 0 Ошибка:  0.00010701538121793419
# Эпоха 13 из 20 Шаг 10 Ошибка:  0.0005573958624154329
# Эпоха 13 из 20 Шаг 20 Ошибка:  0.0019745538011193275
# Эпоха 13 из 20 Шаг 30 Ошибка:  0.0019080806523561478
# Эпоха 13 из 20 Шаг 40 Ошибка:  0.0006817730027250946
# Эпоха 13 из 20 Шаг 50 Ошибка:  0.00031043816125020385
# Эпоха 13 из 20 Шаг 60 Ошибка:  0.00024146123905666173
# Эпоха 13 из 20 Шаг 70 Ошибка:  0.0014603486051782966
# Эпоха 13 из 20 Шаг 80 Ошибка:  0.0012122254120185971
# Эпоха 13 из 20 Шаг 90 Ошибка:  0.0020338522735983133
# Эпоха 13 из 20 Шаг 100 Ошибка:  0.0009391711209900677
# Эпоха 13 из 20 Шаг 110 Ошибка:  0.0037721223197877407
# Эпоха 13 из 20 Шаг 120 Ошибка:  0.0008407306158915162
# Эпоха 13 из 20 Шаг 130 Ошибка:  0.0002756610047072172
# Эпоха 13 из 20 Шаг 140 Ошибка:  0.0002956945972982794
# Эпоха 13 из 20 Шаг 150 Ошибка:  0.0016973409801721573
# Эпоха 13 из 20 Шаг 160 Ошибка:  0.0019661716651171446
# Эпоха 13 из 20 Шаг 170 Ошибка:  0.001945111551322043
# Эпоха 13 из 20 Шаг 180 Ошибка:  0.0008313154685311019
# Эпоха 13 из 20 Шаг 190 Ошибка:  0.0034061770420521498
# Epoch 15/20: Эпоха 14 из 20 Шаг 0 Ошибка:  0.00041443650843575597
# Эпоха 14 из 20 Шаг 10 Ошибка:  0.002084387233480811
# Эпоха 14 из 20 Шаг 20 Ошибка:  0.00043214508332312107
# Эпоха 14 из 20 Шаг 30 Ошибка:  0.00012080372835043818
# Эпоха 14 из 20 Шаг 40 Ошибка:  0.0013258751714602113
# Эпоха 14 из 20 Шаг 50 Ошибка:  4.695952156907879e-05
# Эпоха 14 из 20 Шаг 60 Ошибка:  0.0022473824210464954
# Эпоха 14 из 20 Шаг 70 Ошибка:  0.0010182323167100549
# Эпоха 14 из 20 Шаг 80 Ошибка:  0.001056457287631929
# Эпоха 14 из 20 Шаг 90 Ошибка:  0.0011459115194156766
# Эпоха 14 из 20 Шаг 100 Ошибка:  0.0004618695820681751
# Эпоха 14 из 20 Шаг 110 Ошибка:  0.0010973484022542834
# Эпоха 14 из 20 Шаг 120 Ошибка:  0.0009125469368882477
# Эпоха 14 из 20 Шаг 130 Ошибка:  7.628417370142415e-05
# Эпоха 14 из 20 Шаг 140 Ошибка:  8.731873094802722e-05
# Эпоха 14 из 20 Шаг 150 Ошибка:  4.115882620681077e-05
# Эпоха 14 из 20 Шаг 160 Ошибка:  0.00035961560206487775
# Эпоха 14 из 20 Шаг 170 Ошибка:  0.00037060436443425715
# Эпоха 14 из 20 Шаг 180 Ошибка:  4.965702100889757e-05
# Эпоха 14 из 20 Шаг 190 Ошибка:  1.2540604984678794e-05
# Epoch 16/20: Эпоха 15 из 20 Шаг 0 Ошибка:  7.133925828384236e-05
# Эпоха 15 из 20 Шаг 10 Ошибка:  0.0007189249154180288
# Эпоха 15 из 20 Шаг 20 Ошибка:  0.00014444452244788408
# Эпоха 15 из 20 Шаг 30 Ошибка:  0.00019588720169849694
# Эпоха 15 из 20 Шаг 40 Ошибка:  0.0002899504324886948
# Эпоха 15 из 20 Шаг 50 Ошибка:  0.0006422431324608624
# Эпоха 15 из 20 Шаг 60 Ошибка:  0.0007658370886929333
# Эпоха 15 из 20 Шаг 70 Ошибка:  0.0001073727835319005
# Эпоха 15 из 20 Шаг 80 Ошибка:  0.0009423214942216873
# Эпоха 15 из 20 Шаг 90 Ошибка:  0.0003322050324641168
# Эпоха 15 из 20 Шаг 100 Ошибка:  0.0002797216584440321
# Эпоха 15 из 20 Шаг 110 Ошибка:  0.002790407743304968
# Эпоха 15 из 20 Шаг 120 Ошибка:  0.0006092415424063802
# Эпоха 15 из 20 Шаг 130 Ошибка:  0.0003662214148789644
# Эпоха 15 из 20 Шаг 140 Ошибка:  0.0005211633397266269
# Эпоха 15 из 20 Шаг 150 Ошибка:  0.000200295660761185
# Эпоха 15 из 20 Шаг 160 Ошибка:  0.0017175758257508278
# Эпоха 15 из 20 Шаг 170 Ошибка:  0.0008455159259028733
# Эпоха 15 из 20 Шаг 180 Ошибка:  1.789260932127945e-05
# Эпоха 15 из 20 Шаг 190 Ошибка:  0.0003736821236088872
# Epoch 17/20: Эпоха 16 из 20 Шаг 0 Ошибка:  0.000992303597740829
# Эпоха 16 из 20 Шаг 10 Ошибка:  0.0005228404188528657
# Эпоха 16 из 20 Шаг 20 Ошибка:  0.0006151053821668029
# Эпоха 16 из 20 Шаг 30 Ошибка:  0.0004998553777113557
# Эпоха 16 из 20 Шаг 40 Ошибка:  0.0007611747132614255
# Эпоха 16 из 20 Шаг 50 Ошибка:  0.0005380931543186307
# Эпоха 16 из 20 Шаг 60 Ошибка:  0.0007784779299981892
# Эпоха 16 из 20 Шаг 70 Ошибка:  1.5329354937421158e-05
# Эпоха 16 из 20 Шаг 80 Ошибка:  0.0005455248756334186
# Эпоха 16 из 20 Шаг 90 Ошибка:  0.0002030211762757972
# Эпоха 16 из 20 Шаг 100 Ошибка:  0.0005544016603380442
# Эпоха 16 из 20 Шаг 110 Ошибка:  0.000932322524022311
# Эпоха 16 из 20 Шаг 120 Ошибка:  8.687870285939425e-05
# Эпоха 16 из 20 Шаг 130 Ошибка:  4.827463271794841e-05
# Эпоха 16 из 20 Шаг 140 Ошибка:  0.00020647115889005363
# Эпоха 16 из 20 Шаг 150 Ошибка:  7.748416101094335e-05
# Эпоха 16 из 20 Шаг 160 Ошибка:  4.732525667350274e-06
# Эпоха 16 из 20 Шаг 170 Ошибка:  0.0017371585126966238
# Эпоха 16 из 20 Шаг 180 Ошибка:  3.544940409483388e-05
# Эпоха 16 из 20 Шаг 190 Ошибка:  0.00021766044665127993
# Epoch 18/20: Эпоха 17 из 20 Шаг 0 Ошибка:  4.196100690023741e-06
# Эпоха 17 из 20 Шаг 10 Ошибка:  0.0009126779623329639
# Эпоха 17 из 20 Шаг 20 Ошибка:  3.646381446742453e-05
# Эпоха 17 из 20 Шаг 30 Ошибка:  0.0003329452592879534
# Эпоха 17 из 20 Шаг 40 Ошибка:  0.0002628591319080442
# Эпоха 17 из 20 Шаг 50 Ошибка:  0.00024988880613818765
# Эпоха 17 из 20 Шаг 60 Ошибка:  5.3622548875864595e-05
# Эпоха 17 из 20 Шаг 70 Ошибка:  1.2182812497485429e-05
# Эпоха 17 из 20 Шаг 80 Ошибка:  0.001275929738767445
# Эпоха 17 из 20 Шаг 90 Ошибка:  0.0006274721818044782
# Эпоха 17 из 20 Шаг 100 Ошибка:  0.00015231550787575543
# Эпоха 17 из 20 Шаг 110 Ошибка:  3.9812854083720595e-05
# Эпоха 17 из 20 Шаг 120 Ошибка:  0.0004143115656916052
# Эпоха 17 из 20 Шаг 130 Ошибка:  5.93443401157856e-05
# Эпоха 17 из 20 Шаг 140 Ошибка:  0.0001344352785963565
# Эпоха 17 из 20 Шаг 150 Ошибка:  0.0011892929906025529
# Эпоха 17 из 20 Шаг 160 Ошибка:  5.678757588611916e-05
# Эпоха 17 из 20 Шаг 170 Ошибка:  0.000969703949522227
# Эпоха 17 из 20 Шаг 180 Ошибка:  0.0006536220898851752
# Эпоха 17 из 20 Шаг 190 Ошибка:  0.00025351266958750784
# Epoch 19/20: Эпоха 18 из 20 Шаг 0 Ошибка:  0.000924820895306766
# Эпоха 18 из 20 Шаг 10 Ошибка:  0.0005961154238320887
# Эпоха 18 из 20 Шаг 20 Ошибка:  1.4901115719112568e-06
# Эпоха 18 из 20 Шаг 30 Ошибка:  9.861565195024014e-05
# Эпоха 18 из 20 Шаг 40 Ошибка:  0.00017531533376313746
# Эпоха 18 из 20 Шаг 50 Ошибка:  1.1789505151682533e-05
# Эпоха 18 из 20 Шаг 60 Ошибка:  0.0005013588233850896
# Эпоха 18 из 20 Шаг 70 Ошибка:  3.223199746571481e-05
# Эпоха 18 из 20 Шаг 80 Ошибка:  3.5762500374403317e-06
# Эпоха 18 из 20 Шаг 90 Ошибка:  0.0018830556655302644
# Эпоха 18 из 20 Шаг 100 Ошибка:  0.0004335773119237274
# Эпоха 18 из 20 Шаг 110 Ошибка:  0.0001105538904084824
# Эпоха 18 из 20 Шаг 120 Ошибка:  0.00026134500512853265
# Эпоха 18 из 20 Шаг 130 Ошибка:  0.0003091170219704509
# Эпоха 18 из 20 Шаг 140 Ошибка:  0.0002791658043861389
# Эпоха 18 из 20 Шаг 150 Ошибка:  0.002403761725872755
# Эпоха 18 из 20 Шаг 160 Ошибка:  1.8214394003734924e-05
# Эпоха 18 из 20 Шаг 170 Ошибка:  0.00028074515284970403
# Эпоха 18 из 20 Шаг 180 Ошибка:  0.0014174487441778183
# Эпоха 18 из 20 Шаг 190 Ошибка:  0.0006938608130440116
# Epoch 20/20: Эпоха 19 из 20 Шаг 0 Ошибка:  0.0003836110117845237
# Эпоха 19 из 20 Шаг 10 Ошибка:  0.00015519399312324822
# Эпоха 19 из 20 Шаг 20 Ошибка:  5.8740773965837434e-05
# Эпоха 19 из 20 Шаг 30 Ошибка:  0.00021722479141317308
# Эпоха 19 из 20 Шаг 40 Ошибка:  0.0006958976155146956
# Эпоха 19 из 20 Шаг 50 Ошибка:  3.096879299846478e-05
# Эпоха 19 из 20 Шаг 60 Ошибка:  2.53072394116316e-05
# Эпоха 19 из 20 Шаг 70 Ошибка:  0.00022073500440455973
# Эпоха 19 из 20 Шаг 80 Ошибка:  2.3268361474038102e-05
# Эпоха 19 из 20 Шаг 90 Ошибка:  0.0012859503040090203
# Эпоха 19 из 20 Шаг 100 Ошибка:  9.049028449226171e-05
# Эпоха 19 из 20 Шаг 110 Ошибка:  3.8989073800621554e-05
# Эпоха 19 из 20 Шаг 120 Ошибка:  0.0015370966866612434
# Эпоха 19 из 20 Шаг 130 Ошибка:  0.000563460576813668
# Эпоха 19 из 20 Шаг 140 Ошибка:  0.0012392172357067466
# Эпоха 19 из 20 Шаг 150 Ошибка:  4.3148356780875474e-05
# Эпоха 19 из 20 Шаг 160 Ошибка:  0.0008536834502592683
# Эпоха 19 из 20 Шаг 170 Ошибка:  0.0002229700330644846
# Эпоха 19 из 20 Шаг 180 Ошибка:  0.0015421815915033221
# Эпоха 19 из 20 Шаг 190 Ошибка:  7.273246592376381e-05
# Time: 396.8030791282654

# %%
correct_predictions = 0
num_test_samples = len(test_sliced)

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        pred = net(images) 
        _, pred_class = torch.max(pred.data, 1) 
        correct_predictions += (pred_class == labels).sum().item()

print('Точность модели: ' + str(100 * correct_predictions / num_test_samples) + '%')
# Out:
# Точность модели: 85.9%

# %%
inputs, classes = next(iter(test_loader))
pred = net(inputs.to(device))
_, pred_class = torch.max(pred.data, 1)


for i,j in zip(inputs, pred_class):
    img = i.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img = std * img + mean
    img = np.clip(img, 0, 1)
    plt.imshow(img)
    plt.title(class_names[j])
    plt.pause(2)

# %%
torch.save(net.state_dict(), 'net.ckpt')
